# %% [markdown]
# # SHAKTI FEniCS code

# %% [markdown]
# The code requires [FEniCS](https://fenicsproject.org)--currently running with v0.8.0.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '../source')

# %% [markdown]
# ## Set model options in setup files and run the code
# ## STEP 1: Run 2-year spinup with no meltwater forcing

# %%
# !mpirun -np 4 python3 ../source/main.py setup_greenland_spinup
# Out:
#         ll2xy: creating coordinates in north polar stereographic (Std Latitude: 70degN Meridian: 45deg)
#         ll2xy: creating coordinates in north polar stereographic (Std Latitude: 70degN Meridian: 45deg)
#         ll2xy: creating coordinates in north polar stereographic (Std Latitude: 70degN Meridian: 45deg)
#         ll2xy: creating coordinates in north polar stereographic (Std Latitude: 70degN Meridian: 45deg)
# Info    : Reading '../meshes/store_mesh.msh'...
# Info    : 207 entities
# Info    : 12976 nodes
# Info    : 25535 elements
# Info    : Done reading '../meshes/store_mesh.msh'
# Time step 17520 of 17520 completed (100.0%)

# %% [markdown]
# ## STEP 2: Run 1-day meltwater injection expriment (lake drainage)

# %%
# !mpirun -np 4 python3 ../source/main.py setup_greenland_lakedrain
# Out:
#         ll2xy: creating coordinates in north polar stereographic (Std Latitude: 70degN Meridian: 45deg)
#         ll2xy: creating coordinates in north polar stereographic (Std Latitude: 70degN Meridian: 45deg)
#         ll2xy: creating coordinates in north polar stereographic (Std Latitude: 70degN Meridian: 45deg)
#         ll2xy: creating coordinates in north polar stereographic (Std Latitude: 70degN Meridian: 45deg)
# Info    : Reading '../meshes/store_mesh.msh'...
# Info    : 207 entities
# Info    : 12976 nodes
# Info    : 25535 elements
# Info    : Done reading '../meshes/store_mesh.msh'
# Time step 240 of 240 completed (100.0%)
